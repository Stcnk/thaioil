# %%
import os
from PyPDF2 import PdfReader

def pdf_to_txt(pdf_path, txt_path):
    reader = PdfReader(pdf_path)
    with open(txt_path, 'w', encoding='utf-8') as txt_file:
        for page in reader.pages:
            text = page.extract_text()
            if text:
                txt_file.write(text)

def process_pdfs_in_folder(folder_path):
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.endswith('.pdf'):
                pdf_path = os.path.join(root, file)
                txt_path = os.path.join(root, os.path.splitext(file)[0] + '.txt')
                pdf_to_txt(pdf_path, txt_path)
                print(f"Converted {file} to {txt_path}")

def main():
    folder_path = r'C:\Users\(Satang)ChanikarnNik\OneDrive - STelligence Co., Ltd\Documents\GitHub\thaioil\Sample_Doc'  # Replace with your folder path
    process_pdfs_in_folder(folder_path)

if __name__ == "__main__":
    main()
# Out:
# Converted API 1004_120.40-095.pdf to C:\Users\(Satang)ChanikarnNik\OneDrive - STelligence Co., Ltd\Documents\GitHub\thaioil\Sample_Doc\Code & Standard\API 1004_120.40-095.txt
# Converted ASME B16.5-2003 Pipe Flanges-Flanged Fittings NPS 12 Through NPS24 MetricInch Standard_120.70-082.pdf to C:\Users\(Satang)ChanikarnNik\OneDrive - STelligence Co., Ltd\Documents\GitHub\thaioil\Sample_Doc\Code & Standard\ASME B16.5-2003 Pipe Flanges-Flanged Fittings NPS 12 Through NPS24 MetricInch Standard_120.70-082.txt
# Converted ASTM Cetane Method For Rating Diesel Fuels 1963_120.80-006.pdf to C:\Users\(Satang)ChanikarnNik\OneDrive - STelligence Co., Ltd\Documents\GitHub\thaioil\Sample_Doc\Code & Standard\ASTM Cetane Method For Rating Diesel Fuels 1963_120.80-006.txt
# Converted IEC 112_120.180-158.pdf to C:\Users\(Satang)ChanikarnNik\OneDrive - STelligence Co., Ltd\Documents\GitHub\thaioil\Sample_Doc\Code & Standard\IEC 112_120.180-158.txt
# ...

# %%
IMS, SAP, Guidelines, International standard, TOSS, DEP, ASME

# %%
pip install unstructured
# Out:
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# ...
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      ------------------------------------- 981.5/981.5 kB 23.2 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached numpy-1.26.4-cp310-cp310-win_amd64.whl.metadata (61 kB)
# ...
#   Using cached tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached marshmallow-3.21.3-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# ...

# %%
pip install "unstructured[all-docs]"
# Out:
# ...
#   Using cached networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Using cached xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached huggingface_hub-0.24.5-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached google_api_core-2.19.1-py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached proto_plus-1.24.0-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached protobuf-5.27.3-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# ...
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# ...
#   Using cached googleapis_common_protos-1.63.2-py2.py3-none-any.whl.metadata (1.5 kB)
# ...
#   Using cached pyasn1_modules-0.4.0-py3-none-any.whl.metadata (3.4 kB)
# ...
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
# ...
